# %% [markdown]
# ## Import Data Source

# %%
import pandas as pd
import numpy as np
import datetime

# %%
# data = "/Users/ruzlim/Code/Jupyter//Raw_Agg_Performance.csv"
# data = "c/Users/Narut4/coding/Jupyter/Raw_Agg_Performance.csv"
data = "Raw_Agg_Performance.csv"

df = pd.read_csv(data)
df.head()

# %% [markdown]
# ## Analyze Data

# %%
df.describe()

# %%
df.shape

# %%
df.dtypes

# %%
df.mean(numeric_only=True)

# %%
# Check null value in each column

df.apply(lambda x: sum(x.isnull()), axis=0)

# %%
# Fullfill null value example

df_tmp = df

df_tmp['TARGET_AGG'].fillna(df_tmp['TARGET_AGG'].mean(), inplace=True)

df_tmp.apply(lambda x: sum(x.isnull()), axis=0)

# df_tmp

# %%
df['CENTER'].unique()

# %% [markdown]
# ## Business Growth

# %%
# df_bg = df[(df['CENTER'] == 'Sales & Revenue') & (df['BG_FLAG'] == 'Y')]
df_bg = df[(df['BG_FLAG'] == 'Y') | ('METRIC_NAME' == 'TDG Revenue (Performance View)')]
df_bg.head()

# %%
df_bg.describe()

# %%
df_bg.shape

# %%
# df_bg.sort_values(by=['TM_KEY_MTH', 'TM_KEY_WK', 'CENTER', 'METRIC_GRP', 'COMP_CD', 'PRODUCT_GRP', 'METRIC_CD'], ascending=True)
# df_bg.head()

# %% [markdown]
# ## Monthly Aggregate

# %%
# df_bg_agg_1 = pd.DataFrame(df_bg.groupby(['TM_KEY_MTH', 'TM_KEY_WK', 'METRIC_CD', 'METRIC_NAME'])['ACTUAL_AGG'].sum().reset_index())
# df_bg_agg_1

# df_bg_agg_2 = pd.DataFrame(df_bg.groupby(['TM_KEY_MTH', 'TM_KEY_WK', 'METRIC_CD', 'METRIC_NAME'])['ACTUAL_AGG'].agg(['sum', 'count']).reset_index())
# df_bg_agg_2

# df_bg_agg = pd.DataFrame(df_bg.groupby(['TM_KEY_MTH', 'TM_KEY_WK', 'METRIC_CD', 'METRIC_NAME']).agg({'ACTUAL_AGG': 'sum', 'TARGET_AGG': 'sum'}).reset_index())
# df_bg_agg['ACTUAL_AGG'] = df_bg_agg['ACTUAL_AGG'] / 1000000
# df_bg_agg['TARGET_AGG'] = df_bg_agg['TARGET_AGG'] / 1000000
# df_bg_agg.head()

# %%
df_bg_agg_actual_mth = pd.DataFrame(df_bg.groupby(['TM_KEY_MTH', 'METRIC_CD', 'METRIC_NAME'])['ACTUAL_AGG'].sum().reset_index())
df_bg_agg_actual_mth.rename(columns={'ACTUAL_AGG': 'AGG'}, inplace=True)
df_bg_agg_actual_mth['MEASURE'] = 'ACTUAL'
df_bg_agg_actual_mth.head()

# %%
df_bg_agg_target_mth = pd.DataFrame(df_bg.groupby(['TM_KEY_MTH', 'METRIC_CD', 'METRIC_NAME'])['TARGET_AGG'].sum().reset_index())
df_bg_agg_target_mth.rename(columns={'TARGET_AGG': 'AGG'}, inplace=True)
df_bg_agg_target_mth['MEASURE'] = 'TARGET'
df_bg_agg_target_mth.head()

# %%
df_bg_agg_mth = pd.concat([df_bg_agg_actual_mth, df_bg_agg_target_mth])
df_bg_agg_mth['AGG'] = df_bg_agg_mth['AGG'] / 1000000
df_bg_agg_mth.head()

# %%
df_bg_agg_mth_pivot = df_bg_agg_mth.pivot(index=['TM_KEY_MTH', 'MEASURE'], columns=['METRIC_CD', 'METRIC_NAME'], values='AGG')
df_bg_agg_mth_pivot

# %%
df_bg_agg_mth_pivot.T

# %% [markdown]
# ## Weekly Aggregate

# %%
df_bg_agg_actual_wk = pd.DataFrame(df_bg.groupby(['TM_KEY_WK', 'METRIC_CD', 'METRIC_NAME'])['ACTUAL_AGG'].sum().reset_index())
df_bg_agg_actual_wk.rename(columns={'ACTUAL_AGG': 'AGG'}, inplace=True)
df_bg_agg_actual_wk['MEASURE'] = 'ACTUAL'
df_bg_agg_actual_wk.head()
# Out:
#    TM_KEY_WK   METRIC_CD                     METRIC_NAME           AGG MEASURE
# 0    2023009   B1R000100                 Prepaid Revenue  6.699010e+08  ACTUAL
# 1    2023009   B2R000100                Postpaid Revenue  1.157226e+09  ACTUAL
# 2    2023009  TB3R000100                     TOL Revenue  1.897132e+08  ACTUAL
# 3    2023009  TB4R000100                     TVS Revenue  4.243065e+07  ACTUAL
# 4    2023009   TNSC00142  TDG Revenue (Performance View)  0.000000e+00  ACTUAL

# %%
df_bg_agg_target_wk = pd.DataFrame(df_bg.groupby(['TM_KEY_WK', 'METRIC_CD', 'METRIC_NAME'])['TARGET_AGG'].sum().reset_index())
df_bg_agg_target_wk.rename(columns={'TARGET_AGG': 'AGG'}, inplace=True)
df_bg_agg_target_wk['MEASURE'] = 'TARGET'
df_bg_agg_target_wk.head()
# Out:
#    TM_KEY_WK   METRIC_CD                     METRIC_NAME           AGG MEASURE
# 0    2023009   B1R000100                 Prepaid Revenue  6.262193e+08  TARGET
# 1    2023009   B2R000100                Postpaid Revenue  1.165612e+09  TARGET
# 2    2023009  TB3R000100                     TOL Revenue  2.051734e+08  TARGET
# 3    2023009  TB4R000100                     TVS Revenue  4.755595e+07  TARGET
# 4    2023009   TNSC00142  TDG Revenue (Performance View)  0.000000e+00  TARGET

# %%
df_bg_agg_wk = pd.concat([df_bg_agg_actual_wk, df_bg_agg_target_wk])
df_bg_agg_wk['AGG'] = df_bg_agg_wk['AGG'] / 1000000
df_bg_agg_wk.head()
# Out:
#    TM_KEY_WK   METRIC_CD                     METRIC_NAME          AGG MEASURE
# 0    2023009   B1R000100                 Prepaid Revenue   669.901008  ACTUAL
# 1    2023009   B2R000100                Postpaid Revenue  1157.226110  ACTUAL
# 2    2023009  TB3R000100                     TOL Revenue   189.713166  ACTUAL
# 3    2023009  TB4R000100                     TVS Revenue    42.430646  ACTUAL
# 4    2023009   TNSC00142  TDG Revenue (Performance View)     0.000000  ACTUAL

# %%
df_bg_agg_wk_pivot = df_bg_agg_wk.pivot(index=['TM_KEY_WK', 'MEASURE'], columns=['METRIC_CD', 'METRIC_NAME'], values='AGG')
df_bg_agg_wk_pivot
# Out:
# METRIC_CD               B1R000100        B2R000100   TB3R000100  TB4R000100
# METRIC_NAME       Prepaid Revenue Postpaid Revenue  TOL Revenue TVS Revenue
# TM_KEY_WK MEASURE
# 2023009   ACTUAL       669.901008      1157.226110   189.713166   42.430646  \
#           TARGET       626.219335      1165.611851   205.173356   47.555946
# 2023010   ACTUAL      1489.022666      2542.704602   495.345550   90.125908
#           TARGET      1464.916905      2560.219921   531.751420  100.809440
# 2023011   ACTUAL      2265.823689      4320.113830   952.874775  171.662212
#           TARGET      2281.464179      4365.499251  1020.472959  191.372497
# 2023012   ACTUAL      3055.198017      5690.431029  1246.037826  223.404091
#           TARGET      3090.841192      5739.945715  1332.357409  249.176747
# 2023013   ACTUAL      3957.430826      7480.288742  1594.478765  314.918953
#           TARGET      3952.692098      7566.681744  1704.092759  461.172292
# 2023014   ACTUAL      1119.646034      1796.362050   297.357600   54.017140
#           TARGET      1122.306286      1824.546824   315.377689   59.556469
# 2023015   ACTUAL      1915.320975      3738.327769   811.312854  147.393232
#           TARGET      1966.023512      3742.821992   868.398705  163.256489
# 2023016   ACTUAL      2708.196763      5094.394930  1104.788064  199.085020
#           TARGET      2791.999798      5104.686973  1183.863639  220.237468
# 2023017   ACTUAL      3584.677321      6654.114487  1405.515708  273.695322
#           TARGET      3639.376740      6672.685694  1506.832153  413.616346
# 2023018   ACTUAL       881.977049      1598.840611   302.013865   32.424082
#           TARGET       869.299484      1601.325381   317.296714   59.556469
# 2023019   ACTUAL      1696.805386      3148.724083   665.094200   64.693808
#           TARGET      1696.016607      3154.018522   702.801628  131.083517
# 2023020   ACTUAL      2279.430558      4323.157480   970.832428   94.190016
#           TARGET      2285.080635      4348.522851  1032.967830  191.372497
#
# METRIC_CD                              TNSC00142
# METRIC_NAME       TDG Revenue (Performance View)
# TM_KEY_WK MEASURE
# 2023009   ACTUAL                        0.000000
#           TARGET                        0.000000
# 2023010   ACTUAL                      572.769624
#           TARGET                      522.000000
# 2023011   ACTUAL                      572.769624
#           TARGET                      522.000000
# 2023012   ACTUAL                      572.769624
#           TARGET                      522.000000
# 2023013   ACTUAL                      572.769624
#           TARGET                      522.000000
# 2023014   ACTUAL                      564.000000
#           TARGET                      535.000000
# 2023015   ACTUAL                      546.000000
#           TARGET                      535.000000
# 2023016   ACTUAL                      539.000000
#           TARGET                      535.000000
# 2023017   ACTUAL                      538.000000
#           TARGET                      535.000000
# 2023018   ACTUAL                      561.000000
#           TARGET                      503.000000
# 2023019   ACTUAL                      561.000000
#           TARGET                      503.000000
# 2023020   ACTUAL                      561.000000
#           TARGET                      503.000000

# %%
output_data = df_bg_agg_wk_pivot.T
output_data
# Out:
# TM_KEY_WK                                      2023009
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                  669.901008   626.219335  \
# B2R000100  Postpaid Revenue                1157.226110  1165.611851
# TB3R000100 TOL Revenue                      189.713166   205.173356
# TB4R000100 TVS Revenue                       42.430646    47.555946
# TNSC00142  TDG Revenue (Performance View)     0.000000     0.000000
#
# TM_KEY_WK                                      2023010
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                 1489.022666  1464.916905  \
# B2R000100  Postpaid Revenue                2542.704602  2560.219921
# TB3R000100 TOL Revenue                      495.345550   531.751420
# TB4R000100 TVS Revenue                       90.125908   100.809440
# TNSC00142  TDG Revenue (Performance View)   572.769624   522.000000
#
# TM_KEY_WK                                      2023011
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                 2265.823689  2281.464179  \
# B2R000100  Postpaid Revenue                4320.113830  4365.499251
# TB3R000100 TOL Revenue                      952.874775  1020.472959
# TB4R000100 TVS Revenue                      171.662212   191.372497
# TNSC00142  TDG Revenue (Performance View)   572.769624   522.000000
#
# TM_KEY_WK                                      2023012
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                 3055.198017  3090.841192  \
# B2R000100  Postpaid Revenue                5690.431029  5739.945715
# TB3R000100 TOL Revenue                     1246.037826  1332.357409
# TB4R000100 TVS Revenue                      223.404091   249.176747
# TNSC00142  TDG Revenue (Performance View)   572.769624   522.000000
#
# TM_KEY_WK                                      2023013               ...
# MEASURE                                         ACTUAL       TARGET  ...
# METRIC_CD  METRIC_NAME                                               ...
# B1R000100  Prepaid Revenue                 3957.430826  3952.692098  ...  \
# B2R000100  Postpaid Revenue                7480.288742  7566.681744  ...
# TB3R000100 TOL Revenue                     1594.478765  1704.092759  ...
# TB4R000100 TVS Revenue                      314.918953   461.172292  ...
# TNSC00142  TDG Revenue (Performance View)   572.769624   522.000000  ...
#
# TM_KEY_WK                                      2023016
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                 2708.196763  2791.999798  \
# B2R000100  Postpaid Revenue                5094.394930  5104.686973
# TB3R000100 TOL Revenue                     1104.788064  1183.863639
# TB4R000100 TVS Revenue                      199.085020   220.237468
# TNSC00142  TDG Revenue (Performance View)   539.000000   535.000000
#
# TM_KEY_WK                                      2023017
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                 3584.677321  3639.376740  \
# B2R000100  Postpaid Revenue                6654.114487  6672.685694
# TB3R000100 TOL Revenue                     1405.515708  1506.832153
# TB4R000100 TVS Revenue                      273.695322   413.616346
# TNSC00142  TDG Revenue (Performance View)   538.000000   535.000000
#
# TM_KEY_WK                                      2023018
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                  881.977049   869.299484  \
# B2R000100  Postpaid Revenue                1598.840611  1601.325381
# TB3R000100 TOL Revenue                      302.013865   317.296714
# TB4R000100 TVS Revenue                       32.424082    59.556469
# TNSC00142  TDG Revenue (Performance View)   561.000000   503.000000
#
# TM_KEY_WK                                      2023019
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                 1696.805386  1696.016607  \
# B2R000100  Postpaid Revenue                3148.724083  3154.018522
# TB3R000100 TOL Revenue                      665.094200   702.801628
# TB4R000100 TVS Revenue                       64.693808   131.083517
# TNSC00142  TDG Revenue (Performance View)   561.000000   503.000000
#
# TM_KEY_WK                                      2023020
# MEASURE                                         ACTUAL       TARGET
# METRIC_CD  METRIC_NAME
# B1R000100  Prepaid Revenue                 2279.430558  2285.080635
# B2R000100  Postpaid Revenue                4323.157480  4348.522851
# TB3R000100 TOL Revenue                      970.832428  1032.967830
# TB4R000100 TVS Revenue                       94.190016   191.372497
# TNSC00142  TDG Revenue (Performance View)   561.000000   503.000000
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Generate Output File

# %%
# output_data.to_csv("Agg Performance.csv")

# %%
# output_data.to_excel("Agg Performance.xlsx")
