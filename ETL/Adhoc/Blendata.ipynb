# %% [markdown]
# # Blendata

# %%
from pyspark.sql import SparkSession
from pyspark.errors import AnalysisException, PySparkException

# %%
# 1. เชื่อมต่อเข้ากับ Spark Cluster
spark = SparkSession.builder \
    .appName("MyDataApp") \
    .getOrCreate()

# 2. ระบุชื่อ Database และ Table ที่ต้องการ (เหมือน SQL)
df = spark.read.table("rfzcdr.agg_daily_extract_day")

# # หรือใช้ SQL query
# df = spark.sql("SELECT * FROM rfzcdr.agg_daily_extract_day LIMIT 10")

# df.show()

# %%
# 1. เชื่อมต่อเข้ากับ Spark Cluster
spark = SparkSession.builder \
    .appName("MyDataApp") \
    .getOrCreate()

try:
    # df = spark.read.table("rfzcdr.agg_daily_extract_day")
    df = spark.sql("SELECT * FROM rfzcdr.agg_daily_extract_day LIMIT 10")#.limit(1)
    pdf = df.toPandas()

except AnalysisException as e:
    # Error ประเภทหาตารางไม่เจอ, พิมพ์ชื่อ Column ผิด, หรือ Syntax SQL ผิด
    print(f"SQL/Analysis Error: {e.desc}")

except OutOfMemoryError:
    # Error กรณีข้อมูลใหญ่เกิน RAM ของเครื่องที่รัน Pandas
    print("Error: ข้อมูลใหญ่เกินไปสำหรับ Pandas กรุณา Filter ข้อมูลก่อน")

except Exception as e:
    # Error อื่นๆ ทั่วไป
    print(f"Generic Error: {e}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # 1. เชื่อมต่อเข้ากับ Spark Cluster
#       2 spark = SparkSession.builder \
#       3     .appName("MyDataApp") \
# ----> 4     .getOrCreate()
#       6 try:
#       7     # df = spark.read.table("rfzcdr.agg_daily_extract_day")
#       8     df = spark.sql("SELECT * FROM rfzcdr.agg_daily_extract_day LIMIT 10")#.limit(1)
#
# File c:\Users\Narut4\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# ...

# %%
# เปิดใช้งาน Arrow ใน Spark Configuration
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")

# หลังจากนั้นเวลาใช้ .toPandas() จะเร็วขึ้นมาก
pandas_df = spark_df.toPandas()
