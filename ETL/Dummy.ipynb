# %% [markdown]
# # Import Vinsight Data

# %%
import os
import glob
import configparser
import oracledb
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Parameter

# %%
config = configparser.ConfigParser()
config.read('../my_config.ini')
config.sections()

TDMDBPR_user = config['TDMDBPR']['username']
TDMDBPR_pwd = config['TDMDBPR']['password']
TDMDBPR_db = config['TDMDBPR']['db']
TDMDBPR_host = config['TDMDBPR']['host']
TDMDBPR_port = config['TDMDBPR']['port']

AKPIPRD_user = config['AKPIPRD']['username']
AKPIPRD_pwd = config['AKPIPRD']['password']
AKPIPRD_db = config['AKPIPRD']['db']
AKPIPRD_host = config['AKPIPRD']['host']
AKPIPRD_port = config['AKPIPRD']['port']

# %%
curr_dt = dt.datetime.now().date()
str_curr_dt = curr_dt.strftime('%Y%m%d')
curr_dt

# raw_dir = f"../data/raw"
# op_file_name = f'Agg_Perf_Nationwide-{str_curr_dt}'
# op_raw_file = f'{raw_dir}/{op_file_name}.csv'
# op_raw_file
# Out:
# datetime.date(2024, 6, 6)

# %% [markdown]
# ## AKPIPRD data

# %%
# AKPIPRD

# conn = oracledb.connect(user=AKPIPRD_user, password=AKPIPRD_pwd, dsn=f'{AKPIPRD_host}:{AKPIPRD_port}/{AKPIPRD_db}')
dsn = f'{AKPIPRD_user}/{AKPIPRD_pwd}@{AKPIPRD_host}:{AKPIPRD_port}/{AKPIPRD_db}'
conn = oracledb.connect(dsn)
print(f'{AKPIPRD_db} : Connected')
cur = conn.cursor()

v_date = (curr_dt, )

query = """
    SELECT *
    FROM (
        SELECT TM_KEY_DAY, METRIC_CD, METRIC_NAME, METRIC_VALUE, COMP_CD, VERSION, AREA_NO, AREA_CD, AREA_DESC, AREA_TYPE, LOAD_DATE, REMARK
            , ROW_NUMBER() OVER(PARTITION BY METRIC_CD, AREA_CD, SUBSTR(TM_KEY_DAY,1,6) ORDER BY TM_KEY_DAY DESC) END_MTH_IND
        FROM AUTOKPI.VW_ACTUAL_AREA_DAILY 
        WHERE METRIC_CD LIKE 'VIN%'
        AND TM_KEY_DAY >= 20240101
        AND AREA_TYPE IN ('P', 'Z')
    ) TMP
    --WHERE END_MTH_IND = 1
    WHERE TM_KEY_DAY LIKE '%01'
    ORDER BY TM_KEY_DAY, METRIC_CD, AREA_NO, AREA_CD 
"""

try:
    print(f'\nExecute query as of {v_date[0]}...')
    cur.execute(query)
    rows = cur.fetchall()
    src_df = pd.DataFrame.from_records(rows, columns=[x[0] for x in cur.description])
    print(f'\ndf : {src_df.shape[0]} rows, {src_df.shape[1]} columns\nDone !!!')

except oracledb.DatabaseError as e:
    print(f'Error with Oracle : {e}')

finally:
    cur.close()
    conn.close()
    print(f'\n{AKPIPRD_db} : Disconnected')
# Out:
# AKPIPRD : Connected
#
# Execute query as of 2024-06-06...
#
# df : 288 rows, 13 columns
# Done !!!
#
# AKPIPRD : Disconnected

# %%
src_df[src_df['TM_KEY_DAY']==20240601].reset_index()
# Out:
#     index  TM_KEY_DAY METRIC_CD                       METRIC_NAME  \
# 0     240    20240601  VIN00019  Broadband Subs Share : AIS & 3BB
# 1     241    20240601  VIN00019  Broadband Subs Share : AIS & 3BB
# 2     242    20240601  VIN00019  Broadband Subs Share : AIS & 3BB
# 3     243    20240601  VIN00019  Broadband Subs Share : AIS & 3BB
# 4     244    20240601  VIN00019  Broadband Subs Share : AIS & 3BB
# 5     245    20240601  VIN00019  Broadband Subs Share : AIS & 3BB
# 6     246    20240601  VIN00019  Broadband Subs Share : AIS & 3BB
# 7     247    20240601  VIN00019  Broadband Subs Share : AIS & 3BB
# 8     248    20240601  VIN00020        Broadband Subs Share : TOL
# 9     249    20240601  VIN00020        Broadband Subs Share : TOL
# 10    250    20240601  VIN00020        Broadband Subs Share : TOL
# 11    251    20240601  VIN00020        Broadband Subs Share : TOL
# 12    252    20240601  VIN00020        Broadband Subs Share : TOL
# 13    253    20240601  VIN00020        Broadband Subs Share : TOL
# 14    254    20240601  VIN00020        Broadband Subs Share : TOL
# 15    255    20240601  VIN00020        Broadband Subs Share : TOL
# 16    256    20240601  VIN00021        Broadband Subs Share : 3BB
# 17    257    20240601  VIN00021        Broadband Subs Share : 3BB
# 18    258    20240601  VIN00021        Broadband Subs Share : 3BB
# 19    259    20240601  VIN00021        Broadband Subs Share : 3BB
# 20    260    20240601  VIN00021        Broadband Subs Share : 3BB
# 21    261    20240601  VIN00021        Broadband Subs Share : 3BB
# 22    262    20240601  VIN00021        Broadband Subs Share : 3BB
# 23    263    20240601  VIN00021        Broadband Subs Share : 3BB
# 24    264    20240601  VIN00022        Broadband Subs Share : AIS
# 25    265    20240601  VIN00022        Broadband Subs Share : AIS
# 26    266    20240601  VIN00022        Broadband Subs Share : AIS
# 27    267    20240601  VIN00022        Broadband Subs Share : AIS
# 28    268    20240601  VIN00022        Broadband Subs Share : AIS
# 29    269    20240601  VIN00022        Broadband Subs Share : AIS
# 30    270    20240601  VIN00022        Broadband Subs Share : AIS
# 31    271    20240601  VIN00022        Broadband Subs Share : AIS
# 32    272    20240601  VIN00023         Broadband Subs Share : NT
# 33    273    20240601  VIN00023         Broadband Subs Share : NT
# 34    274    20240601  VIN00023         Broadband Subs Share : NT
# 35    275    20240601  VIN00023         Broadband Subs Share : NT
# 36    276    20240601  VIN00023         Broadband Subs Share : NT
# 37    277    20240601  VIN00023         Broadband Subs Share : NT
# 38    278    20240601  VIN00023         Broadband Subs Share : NT
# 39    279    20240601  VIN00023         Broadband Subs Share : NT
# 40    280    20240601  VIN00024        Broadband Subs Share : CAT
# 41    281    20240601  VIN00024        Broadband Subs Share : CAT
# 42    282    20240601  VIN00024        Broadband Subs Share : CAT
# 43    283    20240601  VIN00024        Broadband Subs Share : CAT
# 44    284    20240601  VIN00024        Broadband Subs Share : CAT
# 45    285    20240601  VIN00024        Broadband Subs Share : CAT
# 46    286    20240601  VIN00024        Broadband Subs Share : CAT
# 47    287    20240601  VIN00024        Broadband Subs Share : CAT
#
#     METRIC_VALUE COMP_CD VERSION  AREA_NO AREA_CD     AREA_DESC AREA_TYPE  \
# 0          46.61    TRUE       A        1       P    Nationwide         P
# 1          37.37    TRUE       A        2     BMA           BMA         Z
# 2          51.22    TRUE       A        2     UPC           UPC         Z
# 3          50.85    TRUE       A        3    EAST          East         Z
# 4          34.53    TRUE       A        4      10       Bangkok         Z
# 5          40.08    TRUE       A        4      11  Samut Prakan         Z
# 6          42.38    TRUE       A        4      12    Nonthaburi         Z
# 7          43.62    TRUE       A        4      13  Pathum Thani         Z
# 8          36.52    TRUE       A        1       P    Nationwide         P
# 9          48.82    TRUE       A        2     BMA           BMA         Z
# 10         30.38    TRUE       A        2     UPC           UPC         Z
# 11         32.59    TRUE       A        3    EAST          East         Z
# 12         50.31    TRUE       A        4      10       Bangkok         Z
# 13         47.47    TRUE       A        4      11  Samut Prakan         Z
# 14         46.30    TRUE       A        4      12    Nonthaburi         Z
# 15         45.35    TRUE       A        4      13  Pathum Thani         Z
# 16         25.68    TRUE       A        1       P    Nationwide         P
# 17         16.21    TRUE       A        2     BMA           BMA         Z
# 18         30.41    TRUE       A        2     UPC           UPC         Z
# 19         27.51    TRUE       A        3    EAST          East         Z
# 20         16.55    TRUE       A        4      10       Bangkok         Z
# 21         16.70    TRUE       A        4      11  Samut Prakan         Z
# 22         15.04    TRUE       A        4      12    Nonthaburi         Z
# 23         15.22    TRUE       A        4      13  Pathum Thani         Z
# 24         20.92    TRUE       A        1       P    Nationwide         P
# 25         21.16    TRUE       A        2     BMA           BMA         Z
# 26         20.81    TRUE       A        2     UPC           UPC         Z
# 27         23.34    TRUE       A        3    EAST          East         Z
# 28         17.98    TRUE       A        4      10       Bangkok         Z
# 29         23.37    TRUE       A        4      11  Samut Prakan         Z
# 30         27.34    TRUE       A        4      12    Nonthaburi         Z
# 31         28.40    TRUE       A        4      13  Pathum Thani         Z
# 32         13.84    TRUE       A        1       P    Nationwide         P
# 33         10.10    TRUE       A        2     BMA           BMA         Z
# 34         15.71    TRUE       A        2     UPC           UPC         Z
# 35         14.84    TRUE       A        3    EAST          East         Z
# 36         11.03    TRUE       A        4      10       Bangkok         Z
# 37          9.17    TRUE       A        4      11  Samut Prakan         Z
# 38          8.52    TRUE       A        4      12    Nonthaburi         Z
# 39          8.08    TRUE       A        4      13  Pathum Thani         Z
# 40          3.03    TRUE       A        1       P    Nationwide         P
# 41          3.70    TRUE       A        2     BMA           BMA         Z
# 42          2.69    TRUE       A        2     UPC           UPC         Z
# 43          1.71    TRUE       A        3    EAST          East         Z
# 44          4.13    TRUE       A        4      10       Bangkok         Z
# 45          3.29    TRUE       A        4      11  Samut Prakan         Z
# 46          2.80    TRUE       A        4      12    Nonthaburi         Z
# 47          2.95    TRUE       A        4      13  Pathum Thani         Z
#
#                     LOAD_DATE REMARK  END_MTH_IND
# 0  2024-06-04 14:37:37.653334   None            9
# 1  2024-06-04 14:37:37.653334   None            9
# 2  2024-06-04 14:37:37.653334   None            9
# 3  2024-06-04 14:37:37.653334   None            9
# 4  2024-06-04 14:37:37.653334   None            9
# 5  2024-06-04 14:37:37.653334   None            9
# 6  2024-06-04 14:37:37.653334   None            9
# 7  2024-06-04 14:37:37.653334   None            9
# 8  2024-06-04 14:38:20.788865   None            9
# 9  2024-06-04 14:38:20.788865   None            9
# 10 2024-06-04 14:38:20.788865   None            9
# 11 2024-06-04 14:38:20.788865   None            9
# 12 2024-06-04 14:38:20.788865   None            9
# 13 2024-06-04 14:38:20.788865   None            9
# 14 2024-06-04 14:38:20.788865   None            9
# 15 2024-06-04 14:38:20.788865   None            9
# 16 2024-06-04 14:38:20.788865   None            9
# 17 2024-06-04 14:38:20.788865   None            9
# 18 2024-06-04 14:38:20.788865   None            9
# 19 2024-06-04 14:38:20.788865   None            9
# 20 2024-06-04 14:38:20.788865   None            9
# 21 2024-06-04 14:38:20.788865   None            9
# 22 2024-06-04 14:38:20.788865   None            9
# 23 2024-06-04 14:38:20.788865   None            9
# 24 2024-06-04 14:38:20.788865   None            9
# 25 2024-06-04 14:38:20.788865   None            9
# 26 2024-06-04 14:38:20.788865   None            9
# 27 2024-06-04 14:38:20.788865   None            9
# 28 2024-06-04 14:38:20.788865   None            9
# 29 2024-06-04 14:38:20.788865   None            9
# 30 2024-06-04 14:38:20.788865   None            9
# 31 2024-06-04 14:38:20.788865   None            9
# 32 2024-06-04 14:38:20.788865   None            9
# 33 2024-06-04 14:38:20.788865   None            9
# 34 2024-06-04 14:38:20.788865   None            9
# 35 2024-06-04 14:38:20.788865   None            9
# 36 2024-06-04 14:38:20.788865   None            9
# 37 2024-06-04 14:38:20.788865   None            9
# 38 2024-06-04 14:38:20.788865   None            9
# 39 2024-06-04 14:38:20.788865   None            9
# 40 2024-06-04 14:38:20.788865   None            9
# 41 2024-06-04 14:38:20.788865   None            9
# 42 2024-06-04 14:38:20.788865   None            9
# 43 2024-06-04 14:38:20.788865   None            9
# 44 2024-06-04 14:38:20.788865   None            9
# 45 2024-06-04 14:38:20.788865   None            9
# 46 2024-06-04 14:38:20.788865   None            9
# 47 2024-06-04 14:38:20.788865   None            9

# %% [markdown]
# ## TDMDBPR data

# %%
# TDMDBPR

# conn = oracledb.connect(user=TDMDBPR_user, password=TDMDBPR_pwd, dsn=f'{TDMDBPR_host}:{TDMDBPR_port}/{TDMDBPR_db}')
dsn = f'{TDMDBPR_user}/{TDMDBPR_pwd}@{TDMDBPR_host}:{TDMDBPR_port}/{TDMDBPR_db}'
conn = oracledb.connect(dsn)
print(f'{TDMDBPR_db} : Connected')
cur = conn.cursor()

v_date = (curr_dt, )

query = """
    SELECT *
    FROM (
        SELECT TM_KEY_DAY, METRIC_CD, METRIC_NAME 
            , CASE 	WHEN AREA_TYPE = 'P' THEN 1
                    WHEN AREA_TYPE = 'Z' THEN (CASE WHEN AREA_CD IN ('BMA', 'UPC') THEN 2 WHEN AREA_CD = 'EAST' THEN 3 ELSE 4 END)
                    WHEN AREA_TYPE = 'G' THEN 5 
                    WHEN AREA_TYPE = 'H' THEN 6 
                    WHEN AREA_TYPE = 'HH' THEN 7
                    ELSE 0 END AREA_NO
            , AREA_TYPE, AREA_CD, AREA_NAME, ACTUAL_SNAP, ACTUAL_AGG, PPN_TM  
        FROM GEOSPCAPPO.AGG_PERF_NEWCO NOLOCK
        WHERE METRIC_CD IN ('VIN00019','VIN00020','VIN00021','VIN00022','VIN00023','VIN00024')
        AND TM_KEY_MTH >= 202401
        AND TM_KEY_DAY LIKE '%01'
        AND AREA_TYPE IN ('P', 'Z')
    )TMP
    ORDER BY TM_KEY_DAY, METRIC_CD, AREA_NO, AREA_CD 
"""

try:
    print(f'\nExecute query as of {v_date[0]}...')
    cur.execute(query)
    rows = cur.fetchall()
    df = pd.DataFrame.from_records(rows, columns=[x[0] for x in cur.description])
    print(f'\ndf : {df.shape[0]} rows, {df.shape[1]} columns\nDone !!!')

except oracledb.DatabaseError as e:
    print(f'Error with Oracle : {e}')

finally:
    cur.close()
    conn.close()
    print(f'\n{TDMDBPR_db} : Disconnected')
# Out:
# TDMDBPR : Connected
#
# Execute query as of 2024-06-06...
#
# df : 240 rows, 10 columns
# Done !!!
#
# TDMDBPR : Disconnected

# %%
df[df['TM_KEY_DAY']==20240601].reset_index()
# Out:
#     index  TM_KEY_DAY METRIC_CD                       METRIC_NAME  AREA_NO  \
# 0     200    20240601  VIN00019  Broadband Subs Share : AIS & 3BB        1
# 1     201    20240601  VIN00019  Broadband Subs Share : AIS & 3BB        2
# 2     202    20240601  VIN00019  Broadband Subs Share : AIS & 3BB        2
# 3     203    20240601  VIN00019  Broadband Subs Share : AIS & 3BB        3
# 4     204    20240601  VIN00019  Broadband Subs Share : AIS & 3BB        4
# 5     205    20240601  VIN00019  Broadband Subs Share : AIS & 3BB        4
# 6     206    20240601  VIN00019  Broadband Subs Share : AIS & 3BB        4
# 7     207    20240601  VIN00019  Broadband Subs Share : AIS & 3BB        4
# 8     208    20240601  VIN00020        Broadband Subs Share : TOL        1
# 9     209    20240601  VIN00020        Broadband Subs Share : TOL        2
# 10    210    20240601  VIN00020        Broadband Subs Share : TOL        2
# 11    211    20240601  VIN00020        Broadband Subs Share : TOL        3
# 12    212    20240601  VIN00020        Broadband Subs Share : TOL        4
# 13    213    20240601  VIN00020        Broadband Subs Share : TOL        4
# 14    214    20240601  VIN00020        Broadband Subs Share : TOL        4
# 15    215    20240601  VIN00020        Broadband Subs Share : TOL        4
# 16    216    20240601  VIN00021        Broadband Subs Share : 3BB        1
# 17    217    20240601  VIN00021        Broadband Subs Share : 3BB        2
# 18    218    20240601  VIN00021        Broadband Subs Share : 3BB        2
# 19    219    20240601  VIN00021        Broadband Subs Share : 3BB        3
# 20    220    20240601  VIN00021        Broadband Subs Share : 3BB        4
# 21    221    20240601  VIN00021        Broadband Subs Share : 3BB        4
# 22    222    20240601  VIN00021        Broadband Subs Share : 3BB        4
# 23    223    20240601  VIN00021        Broadband Subs Share : 3BB        4
# 24    224    20240601  VIN00022        Broadband Subs Share : AIS        1
# 25    225    20240601  VIN00022        Broadband Subs Share : AIS        2
# 26    226    20240601  VIN00022        Broadband Subs Share : AIS        2
# 27    227    20240601  VIN00022        Broadband Subs Share : AIS        3
# 28    228    20240601  VIN00022        Broadband Subs Share : AIS        4
# 29    229    20240601  VIN00022        Broadband Subs Share : AIS        4
# 30    230    20240601  VIN00022        Broadband Subs Share : AIS        4
# 31    231    20240601  VIN00022        Broadband Subs Share : AIS        4
# 32    232    20240601  VIN00023         Broadband Subs Share : NT        1
# 33    233    20240601  VIN00023         Broadband Subs Share : NT        2
# 34    234    20240601  VIN00023         Broadband Subs Share : NT        2
# 35    235    20240601  VIN00023         Broadband Subs Share : NT        3
# 36    236    20240601  VIN00023         Broadband Subs Share : NT        4
# 37    237    20240601  VIN00023         Broadband Subs Share : NT        4
# 38    238    20240601  VIN00023         Broadband Subs Share : NT        4
# 39    239    20240601  VIN00023         Broadband Subs Share : NT        4
#
#    AREA_TYPE AREA_CD     AREA_NAME  ACTUAL_SNAP  ACTUAL_AGG  \
# 0          P       P    Nationwide        46.61       46.61
# 1          Z     BMA           BMA        37.37       37.37
# 2          Z     UPC           UPC        51.22       51.22
# 3          Z    EAST          EAST        50.85       50.85
# 4          Z      10       Bangkok        34.53       34.53
# 5          Z      11  Samut Prakan        40.08       40.08
# 6          Z      12    Nonthaburi        42.38       42.38
# 7          Z      13  Pathum Thani        43.62       43.62
# 8          P       P    Nationwide        36.52       36.52
# 9          Z     BMA           BMA        48.82       48.82
# 10         Z     UPC           UPC        30.38       30.38
# 11         Z    EAST          EAST        32.59       32.59
# 12         Z      10       Bangkok        50.31       50.31
# 13         Z      11  Samut Prakan        47.47       47.47
# 14         Z      12    Nonthaburi        46.30       46.30
# 15         Z      13  Pathum Thani        45.35       45.35
# 16         P       P    Nationwide        25.68       25.68
# 17         Z     BMA           BMA        16.21       16.21
# 18         Z     UPC           UPC        30.41       30.41
# 19         Z    EAST          EAST        27.51       27.51
# 20         Z      10       Bangkok        16.55       16.55
# 21         Z      11  Samut Prakan        16.70       16.70
# 22         Z      12    Nonthaburi        15.04       15.04
# 23         Z      13  Pathum Thani        15.22       15.22
# 24         P       P    Nationwide        20.92       20.92
# 25         Z     BMA           BMA        21.16       21.16
# 26         Z     UPC           UPC        20.81       20.81
# 27         Z    EAST          EAST        23.34       23.34
# 28         Z      10       Bangkok        17.98       17.98
# 29         Z      11  Samut Prakan        23.37       23.37
# 30         Z      12    Nonthaburi        27.34       27.34
# 31         Z      13  Pathum Thani        28.40       28.40
# 32         P       P    Nationwide        16.87       16.87
# 33         Z     BMA           BMA        13.80       13.80
# 34         Z     UPC           UPC        18.40       18.40
# 35         Z    EAST          EAST        16.55       16.55
# 36         Z      10       Bangkok        15.16       15.16
# 37         Z      11  Samut Prakan        12.46       12.46
# 38         Z      12    Nonthaburi        11.32       11.32
# 39         Z      13  Pathum Thani        11.03       11.03
#
#                 PPN_TM
# 0  2024-06-06 01:12:45
# 1  2024-06-06 01:12:45
# 2  2024-06-06 01:12:45
# 3  2024-06-06 01:12:45
# 4  2024-06-06 01:12:45
# 5  2024-06-06 01:12:45
# 6  2024-06-06 01:12:45
# 7  2024-06-06 01:12:45
# 8  2024-06-06 01:12:45
# 9  2024-06-06 01:12:45
# 10 2024-06-06 01:12:45
# 11 2024-06-06 01:12:45
# 12 2024-06-06 01:12:45
# 13 2024-06-06 01:12:45
# 14 2024-06-06 01:12:45
# 15 2024-06-06 01:12:45
# 16 2024-06-06 01:12:45
# 17 2024-06-06 01:12:45
# 18 2024-06-06 01:12:45
# 19 2024-06-06 01:12:45
# 20 2024-06-06 01:12:45
# 21 2024-06-06 01:12:45
# 22 2024-06-06 01:12:45
# 23 2024-06-06 01:12:45
# 24 2024-06-06 01:12:45
# 25 2024-06-06 01:12:45
# 26 2024-06-06 01:12:45
# 27 2024-06-06 01:12:45
# 28 2024-06-06 01:12:45
# 29 2024-06-06 01:12:45
# 30 2024-06-06 01:12:45
# 31 2024-06-06 01:12:45
# 32 2024-06-06 01:12:45
# 33 2024-06-06 01:12:45
# 34 2024-06-06 01:12:45
# 35 2024-06-06 01:12:45
# 36 2024-06-06 01:12:45
# 37 2024-06-06 01:12:45
# 38 2024-06-06 01:12:45
# 39 2024-06-06 01:12:45

# %% [markdown]
# ## Generate Output file

# %%
# df.to_csv(f'{op_raw_file}', index=False, encoding='utf-8')

# print(f'\n"{op_raw_file}" is generated')
# Out:
# "../data/raw/Agg_Perf_Nationwide-20240605.csv" is generated
